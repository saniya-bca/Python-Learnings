# %%
# Sequential algorithm
#1.Calculate the sum of 2 numbers.
a=int(input("enter a no:"))
b=int(input("enter a no:"))
sum= a+b
print(sum)
# Out:
# enter a no:6
# enter a no:5
# 11

# %%
#2.Calculate the area of rectangle(formula: length*breadth)
l=int(input("Enter the length of the rectangle:"))
b=int(input("Enter the breadth of the rectangle:"))
area=l*b
print("The area of the rectangle is:", area)
# Out:
# Enter the length of the rectangle:67
# Enter the breadth of the rectangle:5
# The area of the rectangle is: 335

# %%
#3.Write a algorithm/program to find area of a triangle.
base=float(input("Enter the base of the triangle:"))
height=float(input("Enter the height of the triangle:"))
area = 0.5 * base * height
print("The area of the triangle is:", area)
# Out:
# Enter the base of the triangle:45
# Enter the height of the triangle:33
# The area of the triangle is: 742.5

# %%
#4.Write an algorithm/ program to find the circumference of a circle (formula is 2* pi * r),Take r value from the user..

#Start

#Input the value of radius (r).

#Set the value of π = 3.14159 (or use built-in constant).

#Calculate circumference using formula:

#C=2×π×r

#Display the circumference.

#End

radius = int(input("Enter the radius of the circle: "))
c = 2 * 3.14  * radius

print("The circumference of the circle is:", c)
# Out:
# Enter the radius of the circle: 6
# The circumference of the circle is: 37.68

# %%
#5.Write a program to take the kilometer value as an input and convert it into a meter.
kilometers = float(input("Enter the value in kilometers: "))

meters = kilometers * 1000

print(kilometers, "Kilometers is equal to", meters, "Meters")
# Out:
# Enter the value in kilometers: 7
# 7.0 Kilometers is equal to 7000.0 Meters

# %%
#6.Calculate the area of square (formula : side * side )

side = int(input("Enter the side of the square: "))
area = side * side
print("The area of the square is:", area)
# Out:
# Enter the side of the square: 6
# The area of the square is: 36

# %%
#7. Take input from the user and find the square.

num = float(input("Enter a number: "))
square = num * num
print("The square of", num, "is:", square)
# Out:
# Enter a number: 8
# The square of 8.0 is: 64.0

# %%
#8.WAP Calculate the square root of the user given number.

import math   # for sqrt function
num = float(input("Enter a number: "))
sqrt_value = math.sqrt(num)
print("The square root of", num, "is:", sqrt_value)


#2nd way::
num = float(input("Enter a number: "))
sqrt_value = num ** 0.5
print("The square root of", num, "is:", sqrt_value)
# Out:
# Enter a number: 6
# The square root of 6.0 is: 2.449489742783178
# Enter a number: 7
# The square root of 7.0 is: 2.6457513110645907

# %%
#9. Calculate the cube of the user given number ( take input from user ).

num = float(input("Enter a number: "))
cube = num ** 3   # or num * num * num
print("The cube of", num, "is:", cube)
# Out:
# Enter a number: 5
# The cube of 5.0 is: 125.0

# %%
#10. Take 3 numbers from the user and calculate the average of that.

num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
num3 = float(input("Enter the third number: "))

average = (num1 + num2 + num3) / 3
print("The average of the three numbers is:", average)
# Out:
# Enter the first number: 8
# Enter the second number: 4
# Enter the third number: 3
# The average of the three numbers is: 5.0

# %%
#11. Find the 3% of 120.

number = 120
percentage = 3

value = (percentage * number) / 100
print(percentage, "% of", number, "is:", value)
# Out:
# 3 % of 120 is: 3.6

# %%
#12. Take marks from the user out of 120 and find what percentage the user gets.

marks_obtained = float(input("Enter marks obtained out of 120: "))
total_marks = 120

percentage = (marks_obtained / total_marks) * 100
print("You scored", percentage, "%")
# Out:
# Enter marks obtained out of 120: 67
# You scored 55.833333333333336 %

# %%
#13. Take a number from the user and Find the remainder if it is divided by 3.

num = int(input("Enter a number: "))
remainder = num % 3

print("The remainder when", num, "is divided by 3 is:", remainder)
# Out:
# Enter a number: 8
# The remainder when 8 is divided by 3 is: 2

# %%
#14. Take input from the user and divide it by 3 such that output should be whole number not decimal(float).

num = int(input("Enter a number: "))
quotient = num // 3
print("The whole number result of", num, "divided by 3 is:", quotient)
# Out:
# Enter a number: 65
# The whole number result of 65 divided by 3 is: 21

# %%
#15. Take a number from the user and show the last digit of that number. Hint: use number 10 for divide.

num = int(input("Enter a number: "))
last_digit = num % 10
print("The last digit of", num, "is:", last_digit)
# Out:
# Enter a number: 55664
# The last digit of 55664 is: 4

# %%
#16. Remove the last digit of any number taken by the user. Hint : use number 10.

num = int(input("Enter a number: "))
new_num = num // 10
print("The number after removing the last digit is:", new_num)
# Out:
# Enter a number: 678
# The number after removing the last digit is: 67

# %%
#17. Add 6 in the 241 such that output would be 2416. Note : 6 and 241 both are numbers.


num1 = 241
num2 = 6

result = int(str(num1) + str(num2))

print("The result is:", result)
# Out:
# The result is: 2416

# %%
#18. Swap the two number. Write a program to take 2 number and swap them.

a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))

# Swapping without temporary variable
a, b = b, a

print("After swapping:")
print("First number:", a)
print("Second number:", b)



#2nd way:::
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))

# Swapping using temporary variable
temp = a
a = b
b = temp

print("After swapping:")
print("First number:", a)
print("Second number:", b)
# Out:
# Enter the first number: 6
# Enter the second number: 7
# After swapping:
# First number: 7
# Second number: 6
# Enter the first number: 5
# Enter the second number: 3
# After swapping:
# First number: 3
# Second number: 5

# %%
########################## conditional alogrithms ##############33

#1.Take a number from user and check its even or odd.

num = int(input("Enter a number: "))

if num % 2 == 0:
    print(num, "is Even")
else:
    print(num, "is Odd")
# Out:
# Enter a number: 5
# 5 is Odd

# %%
#2.Take 2 number from user and check which is greater.

num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))

if num1 > num2:
    print(num1, "is greater")
elif num2 > num1:
    print(num2, "is greater")
else:
    print("Both numbers are equal")
# Out:
# Enter the first number: 7
# Enter the second number: 3
# 7 is greater

# %%
#3. Write a program to take 3 number as input and check which is greatest one.

num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
num3 = float(input("Enter the third number: "))

if num1 > num2 and num1 > num3:
    greatest = num1
elif num2 > num1 and num2 > num3:
    greatest = num2
else:
    greatest = num3

print("The greatest number is:", greatest)
# Out:
# Enter the first number: 7
# Enter the second number: 6
# Enter the third number: 4
# The greatest number is: 7.0

# %%
#4. Write a program to take 3 number as input and check which one is smallest among all 3.

num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
num3 = int(input("Enter the third number: "))

# Finding smallest
if num1 < num2 and num1 < num3:
    smallest = num1
elif num2 < num1 and num2 < num3:
    smallest = num2
else:
    smallest = num3

print("The smallest number is:", smallest)
# Out:
# Enter the first number: 5
# Enter the second number: 67
# Enter the third number: 4
# The smallest number is: 4

# %%
#5. Write a program to take a number from user and check it is divisible by 5 or not.

num = int(input("Enter a number: "))

# Checking divisibility
if num % 5 == 0:
    print(num, "is divisible by 5")
else:
    print(num, "is not divisible by 5")
# Out:
# Enter a number: 45
# 45 is divisible by 5

# %%
#6. Write a program to check the last digit of a number is divisible of 2 or not.

num = int(input("Enter a number: "))

# Finding last digit
last_digit = num % 10

# Checking divisibility by 2
if last_digit % 2 == 0:
    print("The last digit", last_digit, "is divisible by 2")
else:
    print("The last digit", last_digit, "is not divisible by 2")
# Out:
# Enter a number: 666
# The last digit 6 is divisible by 2

# %%
#7. Write a program to check the number is divisible of 3 and 9 or not.

num = int(input("Enter a number: "))

# Checking divisibility
if num % 3 == 0 and num % 9 == 0:
    print(num, "is divisible by both 3 and 9")
elif num % 3 == 0:
    print(num, "is divisible by 3 but not by 9")
else:
    print(num, "is not divisible by 3 or 9")
# Out:
# Enter a number: 45
# 45 is divisible by both 3 and 9

# %%
#8. Write a program to the character is vowel or not.

char = input("Enter a character: ").lower()  # convert to lowercase

# Checking if it is a vowel
if char in ['a', 'e', 'i', 'o', 'u']:
    print(char, "is a vowel")
else:
    print(char, "is not a vowel")
# Out:
# Enter a character: E
# e is a vowel

# %%
## doubt
#9. Write a program to take a string and check the string have vowel or not.

string = input("Enter a string: ").lower()  # convert to lowercase

# Checking for vowels
vowels = ['a', 'e', 'i', 'o', 'u']
has_vowel = False

for char in string:
    if char in vowels:
        has_vowel = True
        break

if has_vowel:
    print("The string contains a vowel")
else:
    print("The string does not contain any vowel")
# Out:
# Enter a string: e
# The string contains a vowel

# %%
#10. Write a program to check whether a person is eligible for voting or not (voting age is >=18).
age = int(input("Enter your age: "))

# Checking eligibility
if age >= 18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# Enter your age: 45
# You are eligible to vote

# %%
#11. Write a program to check whether a person is senior citizen or not. If the age is > 60 then.

age = int(input("Enter your age: "))

if age > 60:
    print("You are a senior citizen")
else:
    print("You are not a senior citizen")
# Out:
# Enter your age: 76
# You are a senior citizen

# %%
#12.Write a program to check the number is positive or negative.


num =int(input("Enter a number: "))
if num > 0:
    print("The number is Positive.")
elif num < 0:
    print("The number is Negative.")
else:
    print("The number is Zero.")
# Out:
# Enter a number: -77
# The number is Negative.

# %%
#13. Write a program to whether a number is divisible by 2 and 3 both.

num = int(input("Enter a number: "))

# Checking divisibility
if num % 2 == 0 and num % 3 == 0:
    print("The number is divisible by both 2 and 3.")
else:
    print("The number is not divisible by both 2 and 3.")
# Out:
# Enter a number: 66
# The number is divisible by both 2 and 3.

# %%
#14. Accept the age of 4 people and display the youngest one.
age1 = int(input("Enter age of person 1: "))
age2 = int(input("Enter age of person 2: "))
age3 = int(input("Enter age of person 3: "))
age4 = int(input("Enter age of person 4: "))

# Finding the youngest age using min() function
youngest = min(age1, age2, age3, age4)

# Displaying the result
print("The youngest age is:", youngest)
# Out:
# Enter age of person 1: 44
# Enter age of person 2: 23
# Enter age of person 3: 43
# Enter age of person 4: 63
# The youngest age is: 23

# %%
#15. Write a program to accept a number from 1 to 7 and display the name of the day like 1 for Sunday, 2 for Monday and so on.

day_num = int(input("Enter a number (1 to 7): "))

# Checking and displaying corresponding day
if day_num == 1:
    print("Sunday")
elif day_num == 2:
    print("Monday")
elif day_num == 3:
    print("Tuesday")
elif day_num == 4:
    print("Wednesday")
elif day_num == 5:
    print("Thursday")
elif day_num == 6:
    print("Friday")
elif day_num == 7:
    print("Saturday")
else:
    print("Invalid input! Please enter a number between 1 and 7.")
# Out:
# Enter a number (1 to 7): 5
# Thursday

# %%
#16. Write a program to accept a number from 1 to 12 and display the name of the month like 1 for January, 2 for Feb. and so on.
month_num = int(input("Enter a number (1 to 12): "))

# Checking and displaying corresponding month
if month_num == 1:
    print("January")
elif month_num == 2:
    print("February")
elif month_num == 3:
    print("March")
elif month_num == 4:
    print("April")
elif month_num == 5:
    print("May")
elif month_num == 6:
    print("June")
elif month_num == 7:
    print("July")
elif month_num == 8:
    print("August")
elif month_num == 9:
    print("September")
elif month_num == 10:
    print("October")
elif month_num == 11:
    print("November")
elif month_num == 12:
    print("December")
else:
    print("Invalid input! Please enter a number between 1 and 12.")
# Out:
# Enter a number (1 to 12): 11
# November

# %%
#17. Write a program to accept two numbers and mathematical operators and perform
#operation accordingly.
#Like : Enter First Number : 7
# Enter Second Number : 9
# Enter Operator : +
# Your Answer is : 16

num1 = int(input("Enter First Number: "))
num2 = int(input("Enter Second Number: "))
operator = input("Enter Operator (+, -, *, /, %): ")

# Performing operation based on operator
if operator == '+':
    result = num1 + num2
elif operator == '-':
    result = num1 - num2
elif operator == '*':
    result = num1 * num2
elif operator == '/':
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error! Division by zero."
elif operator == '%':
    if num2 != 0:
        result = num1 % num2
    else:
        result = "Error! Division by zero."
else:
    result = "Invalid operator!"

# Displaying the result
print("Your Answer is:", result)
# Out:
# Enter First Number: 7
# Enter Second Number: 9
# Enter Operator (+, -, *, /, %): +
# Your Answer is: 16

# %%
#18. Accept the marks of Eng, Math, Science and Social Science subject and display the stream
#allotted according to following: ---
#All subject total more than 80 marks ---- science stream
#Total < 80 and above 50 ---- Commerce Stream
#Total < 50 ---- Humanities.

eng = int(input("Enter marks in English: "))
math = int(input("Enter marks in Math: "))
sci = int(input("Enter marks in Science: "))
ss = int(input("Enter marks in Social Science: "))

# Calculating total marks
total = eng + math + sci + ss

# Checking conditions and displaying stream
if total > 80:
    print("Science Stream")
elif total > 50:  # total <= 80 automatically
    print("Commerce Stream")
else:  # total <= 50
    print("Humanities")
# Out:
# Enter marks in English: 55
# Enter marks in Math: 67
# Enter marks in Science: 88
# Enter marks in Social Science: 54
# Science Stream

# %%
#19. Accept the electric unit from user and calculate the bill according to following rates.
#First 100 Units : Free
#Next 200 Units : Rs 2 per day.
#Above 300 Units : Rs 5 per day.
#If number of unit is 500 then total bill = 0 + 400 + 1000 = 1400

units = int(input("Enter the number of electricity units consumed: "))

# Initializing bill
bill = 0

# Calculating bill based on units
if units <= 100:
    bill = 0
elif units <= 300:  # 101 to 300
    bill = (units - 100) * 2
else:  # Above 300
    bill = (200 * 2) + ((units - 300) * 5)

# Displaying the total bill
print("Total Electricity Bill: Rs", bill)
# Out:
# Enter the number of electricity units consumed: 56667
# Total Electricity Bill: Rs 282235

# %%
#doubt
#20. Accept the age and the gender (“Male”, “Female”), Number of days and display the
#wages(salary) accordingly.
#Age Gender      Wage/day
#Age >= 18 and Age<30  Gender == “M”  700
#Gender == “F” 					  750
#Age >= 30 and Age<40	    Gender == “M”		800
#Gender == “F”  850

age = int(input("Enter your age: "))
gender = input("Enter your gender (M/F): ").upper()
days = int(input("Enter number of days worked: "))

# Initialize wage per day
wage_per_day = 0

# Determining wage per day based on age and gender
if 18 <= age < 30:
    if gender == "M":
        wage_per_day = 700
    elif gender == "F":
        wage_per_day = 750
elif 30 <= age < 40:
    if gender == "M":
        wage_per_day = 800
    elif gender == "F":
        wage_per_day = 850
else:
    print("No wage rate defined for your age.")

# Calculating total wage
if wage_per_day != 0:
    total_wage = wage_per_day * days
    print("Total Wages: Rs", total_wage)
# Out:
# Enter your age: 67
# Enter your gender (M/F): f
# Enter number of days worked: 567
# No wage rate defined for your age.

# %%
################### Iterative Algorithm.#####################
#1. Write an algorithm/program to print the number from 1 to 10.
