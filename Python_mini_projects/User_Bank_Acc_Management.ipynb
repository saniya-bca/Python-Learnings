# %%
################## project 2: ######################

# %%
#Q.2]
#Create a Python program to build a simple Bank Account Management System using the concepts of Object-Oriented Programming (OOP).
#The system should contain two classes — user and bank — where bank inherits properties and methods from user.
#The program should demonstrate inheritance, constructors, encapsulation, and private variables.

# %%
class user():
  def __init__(self,name,age,gender):
    self.name=name
    self.age=age
    self.gender=gender
  def showdetail(self):
    print("personal detail: ")
    print(f" name: {self.name.title()}")
    print(f" age: {self.age}")
    print(f" gender: {self.gender.title()}")

# %%
user1=user("saniya",21,"female")

# %%
user1.showdetail()
# Out:
# personal detail:
#  name: Saniya
#  age: 21
#  gender: Female

# %%
class bank(user):
  __balance=0
  __usercount=0

  def __init__(self,name,age,gender):
    super().__init__(name,age,gender)
    bank.__usercount +=1
    self.accountno=f"Denabank000 {bank.__usercount}"
  def ud(self):
    return self.__usercount

  def deposite (self, amount):
    self.amount =amount
    self.__balance += self.amount
    print(f"account balance is updated: rs. {self.__balance}")

def withdraw(self, amount):
  self.amount= amount
  if(self.amount> self.__balance):
    print(f"insuffi amount, balance avilable:- rs. {self.__balance}")
  elif(100<=self.amount<=self.__balance):
    print("thank you for visiting")
    self._balance -=self.amount
    print(f"current balance is :- re {self.__balance}")
  else:
    print(f"you cannot withdraw less than 100")

def viewbalance(self):
  self.showdetail()
  print(f"ac no: {self.accountno}")
  print(f"current balance is:- {self.__balance}")


def transfer(self, username, amount):
  self.amount =amount
  if(self.amount>self.__balance):
    print(f"insuffi amount, balance avilable: rs{self.__balance}")
  elif(1<=self.amount<=self.__balance):
    username._balance +=self.amount
    self. balance-=self.amount
    print("amount tranfered successfully")
    print(f"current balance is:- {self.__balance}")

  else:

   print("you cannot tranfer less then rs .1")

# %%
user2=bank("siddhi",22,"female")

# %%
user2.accountno
# Out:
# 'Denabank000 1'

# %%
user2.ud()
# Out:
# 1

# %%
def deposite (self, amount):
  self.amount =amount
  self.__balance += self.amount
  print(f"account balance is updated: rs. {self.__balance}")

def withdraw(self, amount):
  self.amount= amount
  if(self.amount> self.__balance):
    print(f"insuffi amount, balance avilable:- rs. {self.__balance}")
  elif(100<=self.amount<=self.__balance):
    print("thank you for visiting")
    self._balance -=self.amount
    print(f"current balance is :- re {self.__balance}")
  else:
    print(f"you cannot withdraw less than 100")

def viewbalance(self):
  self.showdetail()
  print(f"ac no: {self.accountno}")
  print(f"current balance is:- {self.__balance}")


def transfer(self, username, amount):
  self.amount =amount
  if(self.amount>self.__balance):
    print(f"insuffi amount, balance avilable: rs{self.__balance}")
  elif(1<=self.amount<=self.__balance):
    username._balance +=self.amount
    self. balance-=self.amount
    print("amount tranfered successfully")
    print(f"current balance is:- {self.__balance}")

  else:

   print("you cannot tranfer less then rs .1")

# %%
neha=bank("neha patil", 23, "female")
manoj=bank("manoj bhoir", 34, "male")

# %%
neha.deposite (25000)
# Out:
# account balance is updated: rs. 25000
