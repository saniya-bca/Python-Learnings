# %%
######## practicals and examples ###########

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_table("chiporders.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.head(100)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# ..       ...       ...                                    ...
# 95        42         1                          Barbacoa Bowl
# 96        42         1                    Chips and Guacamole
# 97        43         1                          Carnitas Bowl
# 98        43         1                        Chicken Burrito
# 99        44         1                           Chicken Bowl
#
#                                    choice_description item_price
# 0                                                 NaN     $2.39
# 1                                        [Clementine]     $3.39
# ...

# %%
df.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
df.tail(200)
# Out:
#       order_id  quantity                     item_name  \
# 4422      1763         1             Canned Soft Drink
# 4423      1764         2                  Chicken Bowl
# 4424      1764         1           Chips and Guacamole
# 4425      1764         1  Chips and Fresh Tomato Salsa
# 4426      1764         1                         Chips
# ...        ...       ...                           ...
# 4617      1833         1                 Steak Burrito
# 4618      1833         1                 Steak Burrito
# 4619      1834         1            Chicken Salad Bowl
# 4620      1834         1            Chicken Salad Bowl
# 4621      1834         1            Chicken Salad Bowl
#
#                                      choice_description item_price
# 4422                                             [Coke]     $1.25
# 4423  [Fresh Tomato Salsa, [Rice, Fajita Vegetables,...    $22.50
# 4424                                                NaN     $4.45
# ...

# %%
df=pd.read_table("sales.csv")
df
# Out:
#     Region,Country,Item Type,Sales Channel,Order Priority,Order Date,Order ID,Ship Date,Units Sold,Unit Price,Unit Cost,Total Revenue,Total Cost,Total Profit
# 0    Middle East and North Africa,Libya,Cosmetics,O...
# 1    North America,Canada,Vegetables,Online,M,11-07...
# 2    Middle East and North Africa,Libya,Baby Food,O...
# 3    Asia,Japan,Cereal,Offline,C,04-10-2010,1614426...
# 4    Sub-Saharan Africa,Chad,Fruits,Offline,H,8/16/...
# ..                                                 ...
# 995  Middle East and North Africa,Azerbaijan,Snacks...
# 996  Europe,Georgia,Baby Food,Offline,H,08-01-2011,...
# 997  Middle East and North Africa,United Arab Emira...
# 998  Europe,Finland,Household,Offline,L,1/25/2016,2...
# 999  Europe,Portugal,Cereal,Offline,C,04-10-2014,81...
#
# [1000 rows x 1 columns]

# %%
df=pd.read_excel("exbook.xlsx")
df
# Out:
#    Sr.NO                                   Books            Author  year  \
# 0      1                  The Discovery of India  Jawaharlal Nehru  1946
# 1      2  The Story of my Experiments with Truth    Mahatma Gandhi  1927
# 2      3                 Glimps of World History           J.Nehru  1934
# 3      4                       A Guide to Health    Mahatma Gandhi  1921
# 4      5                           Ignited Minds   APJ Abdul Kalam  2002
# 5      6                           Wings of Fire   APJ Abdul Kalam  1999
#
#      Price  Profit
# 0   599.95    0.30
# 1   159.00    0.30
# 2   750.46    0.24
# 3   250.00    0.25
# 4   300.00    0.10
# 5  1275.25    0.10

# %%
# !pip install xlrd

# %%
# !pip install openpyxl

# %%
df=pd.read_table("course.csv",sep=",")
df
# Out:
#      1     Mumbai        PQR institute .Pvt            BI  MH   9 Months
# 0    2      Delhi    ABC institute .Pvt.LTD            AI  UP  18 Months
# 1    3  Bengaluru       MNO  institute .Ltd  Data Science  TN  11 Months
# 2    4     Bhopal   RST  institute .Pvt.LTD            ML  MP   3 Months
# 3    5     Mumbai   EFG  institute .Pvt.LTD            DL  MH   3 Months
# 4    6  Hyderabad           LMN  institute          Could  AP   4 Months
# 5    7      Patna      DEF   institute .Ltd      Web Serv  BH   4 Months
# 6    8    Channai   PQR  institute .Pvt.LTD           AWS  KT   3 Months
# 7    9    Kolkata       UVW  institute .Ltd    Networking  WB   3 Months
# 8   10  Hyderabad      GHI   institute .Ltd            AI  AP  18 Months
# 9   11     Bhopal          IJK   institute             DL  MP   3 Months
# 10  12       Pune      KLM   institute .Ltd  Data Science  MH  11 Months
# 11  13      Delhi       STU  institute .Ltd            BI  UP   6 Months
# ...

# %%
df=pd.read_table("psd.user.txt",sep="|")
df
# Out:
#        1  24  M     technician  85711
# 0      2  53  F          other  94043
# 1      3  23  M         writer  32067
# 2      4  24  M     technician  43537
# 3      5  33  F          other  15213
# 4      6  42  M      executive  98101
# ..   ...  .. ..            ...    ...
# 937  939  26  F        student  33319
# 938  940  32  M  administrator  02215
# 939  941  20  M        student  97229
# 940  942  48  F      librarian  78209
# 941  943  22  M        student  77841
#
# [942 rows x 5 columns]

# %%
col=["sr","city","institute","course","state","time"]

# %%
a=pd.read_table("course.csv",sep=",",names=col)

# %%
a
# Out:
#     sr       city                 institute        course state       time
# 0    1     Mumbai        PQR institute .Pvt            BI    MH   9 Months
# 1    2      Delhi    ABC institute .Pvt.LTD            AI    UP  18 Months
# 2    3  Bengaluru       MNO  institute .Ltd  Data Science    TN  11 Months
# 3    4     Bhopal   RST  institute .Pvt.LTD            ML    MP   3 Months
# 4    5     Mumbai   EFG  institute .Pvt.LTD            DL    MH   3 Months
# 5    6  Hyderabad           LMN  institute          Could    AP   4 Months
# 6    7      Patna      DEF   institute .Ltd      Web Serv    BH   4 Months
# 7    8    Channai   PQR  institute .Pvt.LTD           AWS    KT   3 Months
# 8    9    Kolkata       UVW  institute .Ltd    Networking    WB   3 Months
# 9   10  Hyderabad      GHI   institute .Ltd            AI    AP  18 Months
# 10  11     Bhopal          IJK   institute             DL    MP   3 Months
# ...

# %%
coll=["sr_no","age","gender","department","Id_no"]

# %%
b=pd.read_table("psd.user.txt",sep="|",names=coll)
b
# Out:
#      sr_no  age gender     department  Id_no
# 0        1   24      M     technician  85711
# 1        2   53      F          other  94043
# 2        3   23      M         writer  32067
# 3        4   24      M     technician  43537
# 4        5   33      F          other  15213
# ..     ...  ...    ...            ...    ...
# 938    939   26      F        student  33319
# 939    940   32      M  administrator  02215
# 940    941   20      M        student  97229
# 941    942   48      F      librarian  78209
# 942    943   22      M        student  77841
#
# [943 rows x 5 columns]

# %%
a.city
# Out:
# 0        Mumbai
# 1         Delhi
# 2     Bengaluru
# 3        Bhopal
# 4        Mumbai
# 5     Hyderabad
# 6         Patna
# 7       Channai
# 8       Kolkata
# 9     Hyderabad
# 10       Bhopal
# 11         Pune
# 12        Delhi
# 13       Mumbai
# 14        Patna
# 15        Surat
# 16        Delhi
# 17       Mumbai
# 18         Pune
# 19    Bengaluru
# 20        Surat
# 21    Hyderabad
# 22       Mumbai
# 23      Channai
# 24        Patna
# Name: city, dtype: object

# %%
a.state
# Out:
# 0     MH
# 1     UP
# 2     TN
# 3     MP
# 4     MH
# 5     AP
# 6     BH
# 7     KT
# 8     WB
# 9     AP
# 10    MP
# 11    MH
# 12    UP
# 13    MH
# 14    BH
# 15    GJ
# 16    UP
# 17    MH
# 18    MH
# 19    TN
# 20    Gj
# 21    AP
# 22    MH
# 23    KT
# 24    BH
# Name: state, dtype: object

# %%
a.city+","+a.state
# Out:
# 0        Mumbai,MH
# 1         Delhi,UP
# 2     Bengaluru,TN
# 3        Bhopal,MP
# 4        Mumbai,MH
# 5     Hyderabad,AP
# 6         Patna,BH
# 7       Channai,KT
# 8       Kolkata,WB
# 9     Hyderabad,AP
# 10       Bhopal,MP
# 11         Pune,MH
# 12        Delhi,UP
# 13       Mumbai,MH
# 14        Patna,BH
# 15        Surat,GJ
# 16        Delhi,UP
# 17       Mumbai,MH
# 18         Pune,MH
# 19    Bengaluru,TN
# 20        Surat,Gj
# 21    Hyderabad,AP
# 22       Mumbai,MH
# 23      Channai,KT
# 24        Patna,BH
# dtype: object

# %%
a["city_state"]=a.city+","+a.state

# %%
a
# Out:
#     sr       city                 institute        course state       time  \
# 0    1     Mumbai        PQR institute .Pvt            BI    MH   9 Months
# 1    2      Delhi    ABC institute .Pvt.LTD            AI    UP  18 Months
# 2    3  Bengaluru       MNO  institute .Ltd  Data Science    TN  11 Months
# 3    4     Bhopal   RST  institute .Pvt.LTD            ML    MP   3 Months
# 4    5     Mumbai   EFG  institute .Pvt.LTD            DL    MH   3 Months
# 5    6  Hyderabad           LMN  institute          Could    AP   4 Months
# 6    7      Patna      DEF   institute .Ltd      Web Serv    BH   4 Months
# 7    8    Channai   PQR  institute .Pvt.LTD           AWS    KT   3 Months
# 8    9    Kolkata       UVW  institute .Ltd    Networking    WB   3 Months
# 9   10  Hyderabad      GHI   institute .Ltd            AI    AP  18 Months
# 10  11     Bhopal          IJK   institute             DL    MP   3 Months
# ...

# %%
b.department
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
#            ...
# 938          student
# 939    administrator
# 940          student
# 941        librarian
# 942          student
# Name: department, Length: 943, dtype: object

# %%
b.Id_no
# Out:
# 0      85711
# 1      94043
# 2      32067
# 3      43537
# 4      15213
#        ...
# 938    33319
# 939    02215
# 940    97229
# 941    78209
# 942    77841
# Name: Id_no, Length: 943, dtype: object

# %%
b.department+","+b.gender+","+b.Id_no
# Out:
# 0         technician,M,85711
# 1              other,F,94043
# 2             writer,M,32067
# 3         technician,M,43537
# 4              other,F,15213
#                ...
# 938          student,F,33319
# 939    administrator,M,02215
# 940          student,M,97229
# 941        librarian,F,78209
# 942          student,M,77841
# Length: 943, dtype: object

# %%
b["work"]=b.department+","+b.gender+","+b.Id_no

# %%
b
# Out:
#      sr_no  age gender     department  Id_no                   work
# 0        1   24      M     technician  85711     technician,M,85711
# 1        2   53      F          other  94043          other,F,94043
# 2        3   23      M         writer  32067         writer,M,32067
# 3        4   24      M     technician  43537     technician,M,43537
# 4        5   33      F          other  15213          other,F,15213
# ..     ...  ...    ...            ...    ...                    ...
# 938    939   26      F        student  33319        student,F,33319
# 939    940   32      M  administrator  02215  administrator,M,02215
# 940    941   20      M        student  97229        student,M,97229
# 941    942   48      F      librarian  78209      librarian,F,78209
# 942    943   22      M        student  77841        student,M,77841
#
# [943 rows x 6 columns]

# %%
a.city_state.head()
# Out:
# 0       Mumbai,MH
# 1        Delhi,UP
# 2    Bengaluru,TN
# 3       Bhopal,MP
# 4       Mumbai,MH
# Name: city_state, dtype: object

# %%
a.city_state.tail()
# Out:
# 20        Surat,Gj
# 21    Hyderabad,AP
# 22       Mumbai,MH
# 23      Channai,KT
# 24        Patna,BH
# Name: city_state, dtype: object

# %%
b.work.head()
# Out:
# 0    technician,M,85711
# 1         other,F,94043
# 2        writer,M,32067
# 3    technician,M,43537
# 4         other,F,15213
# Name: work, dtype: object

# %%
b.work.tail()
# Out:
# 938          student,F,33319
# 939    administrator,M,02215
# 940          student,M,97229
# 941        librarian,F,78209
# 942          student,M,77841
# Name: work, dtype: object

# %%
a.drop("city",axis=1)
# Out:
#     sr                 institute        course state       time    city_state
# 0    1        PQR institute .Pvt            BI    MH   9 Months     Mumbai,MH
# 1    2    ABC institute .Pvt.LTD            AI    UP  18 Months      Delhi,UP
# 2    3       MNO  institute .Ltd  Data Science    TN  11 Months  Bengaluru,TN
# 3    4   RST  institute .Pvt.LTD            ML    MP   3 Months     Bhopal,MP
# 4    5   EFG  institute .Pvt.LTD            DL    MH   3 Months     Mumbai,MH
# 5    6           LMN  institute          Could    AP   4 Months  Hyderabad,AP
# 6    7      DEF   institute .Ltd      Web Serv    BH   4 Months      Patna,BH
# 7    8   PQR  institute .Pvt.LTD           AWS    KT   3 Months    Channai,KT
# 8    9       UVW  institute .Ltd    Networking    WB   3 Months    Kolkata,WB
# 9   10      GHI   institute .Ltd            AI    AP  18 Months  Hyderabad,AP
# 10  11          IJK   institute             DL    MP   3 Months     Bhopal,MP
# ...

# %%
a
# Out:
#     sr       city                 institute        course state       time  \
# 0    1     Mumbai        PQR institute .Pvt            BI    MH   9 Months
# 1    2      Delhi    ABC institute .Pvt.LTD            AI    UP  18 Months
# 2    3  Bengaluru       MNO  institute .Ltd  Data Science    TN  11 Months
# 3    4     Bhopal   RST  institute .Pvt.LTD            ML    MP   3 Months
# 4    5     Mumbai   EFG  institute .Pvt.LTD            DL    MH   3 Months
# 5    6  Hyderabad           LMN  institute          Could    AP   4 Months
# 6    7      Patna      DEF   institute .Ltd      Web Serv    BH   4 Months
# 7    8    Channai   PQR  institute .Pvt.LTD           AWS    KT   3 Months
# 8    9    Kolkata       UVW  institute .Ltd    Networking    WB   3 Months
# 9   10  Hyderabad      GHI   institute .Ltd            AI    AP  18 Months
# 10  11     Bhopal          IJK   institute             DL    MP   3 Months
# ...

# %%
a.drop("city",axis=1,inplace=True)

# %%
a
# Out:
#     sr                 institute        course state       time    city_state
# 0    1        PQR institute .Pvt            BI    MH   9 Months     Mumbai,MH
# 1    2    ABC institute .Pvt.LTD            AI    UP  18 Months      Delhi,UP
# 2    3       MNO  institute .Ltd  Data Science    TN  11 Months  Bengaluru,TN
# 3    4   RST  institute .Pvt.LTD            ML    MP   3 Months     Bhopal,MP
# 4    5   EFG  institute .Pvt.LTD            DL    MH   3 Months     Mumbai,MH
# 5    6           LMN  institute          Could    AP   4 Months  Hyderabad,AP
# 6    7      DEF   institute .Ltd      Web Serv    BH   4 Months      Patna,BH
# 7    8   PQR  institute .Pvt.LTD           AWS    KT   3 Months    Channai,KT
# 8    9       UVW  institute .Ltd    Networking    WB   3 Months    Kolkata,WB
# 9   10      GHI   institute .Ltd            AI    AP  18 Months  Hyderabad,AP
# 10  11          IJK   institute             DL    MP   3 Months     Bhopal,MP
# ...

# %%
b.drop(["sr_no","work"],axis=1)
# Out:
#      age gender     department  Id_no
# 0     24      M     technician  85711
# 1     53      F          other  94043
# 2     23      M         writer  32067
# 3     24      M     technician  43537
# 4     33      F          other  15213
# ..   ...    ...            ...    ...
# 938   26      F        student  33319
# 939   32      M  administrator  02215
# 940   20      M        student  97229
# 941   48      F      librarian  78209
# 942   22      M        student  77841
#
# [943 rows x 4 columns]

# %%
b
# Out:
#      sr_no  age gender     department  Id_no                   work
# 0        1   24      M     technician  85711     technician,M,85711
# 1        2   53      F          other  94043          other,F,94043
# 2        3   23      M         writer  32067         writer,M,32067
# 3        4   24      M     technician  43537     technician,M,43537
# 4        5   33      F          other  15213          other,F,15213
# ..     ...  ...    ...            ...    ...                    ...
# 938    939   26      F        student  33319        student,F,33319
# 939    940   32      M  administrator  02215  administrator,M,02215
# 940    941   20      M        student  97229        student,M,97229
# 941    942   48      F      librarian  78209      librarian,F,78209
# 942    943   22      M        student  77841        student,M,77841
#
# [943 rows x 6 columns]

# %%
b.drop(["sr_no","work"],axis=1,inplace=True)

# %%
b
# Out:
#      age gender     department  Id_no
# 0     24      M     technician  85711
# 1     53      F          other  94043
# 2     23      M         writer  32067
# 3     24      M     technician  43537
# 4     33      F          other  15213
# ..   ...    ...            ...    ...
# 938   26      F        student  33319
# 939   32      M  administrator  02215
# 940   20      M        student  97229
# 941   48      F      librarian  78209
# 942   22      M        student  77841
#
# [943 rows x 4 columns]

# %%
a.drop(2,axis=0)
# Out:
#     sr                 institute        course state       time    city_state
# 0    1        PQR institute .Pvt            BI    MH   9 Months     Mumbai,MH
# 1    2    ABC institute .Pvt.LTD            AI    UP  18 Months      Delhi,UP
# 3    4   RST  institute .Pvt.LTD            ML    MP   3 Months     Bhopal,MP
# 4    5   EFG  institute .Pvt.LTD            DL    MH   3 Months     Mumbai,MH
# 5    6           LMN  institute          Could    AP   4 Months  Hyderabad,AP
# 6    7      DEF   institute .Ltd      Web Serv    BH   4 Months      Patna,BH
# 7    8   PQR  institute .Pvt.LTD           AWS    KT   3 Months    Channai,KT
# 8    9       UVW  institute .Ltd    Networking    WB   3 Months    Kolkata,WB
# 9   10      GHI   institute .Ltd            AI    AP  18 Months  Hyderabad,AP
# 10  11          IJK   institute             DL    MP   3 Months     Bhopal,MP
# 11  12      KLM   institute .Ltd  Data Science    MH  11 Months       Pune,MH
# ...

# %%
a
# Out:
#     sr                 institute        course state       time    city_state
# 0    1        PQR institute .Pvt            BI    MH   9 Months     Mumbai,MH
# 1    2    ABC institute .Pvt.LTD            AI    UP  18 Months      Delhi,UP
# 2    3       MNO  institute .Ltd  Data Science    TN  11 Months  Bengaluru,TN
# 3    4   RST  institute .Pvt.LTD            ML    MP   3 Months     Bhopal,MP
# 4    5   EFG  institute .Pvt.LTD            DL    MH   3 Months     Mumbai,MH
# 5    6           LMN  institute          Could    AP   4 Months  Hyderabad,AP
# 6    7      DEF   institute .Ltd      Web Serv    BH   4 Months      Patna,BH
# 7    8   PQR  institute .Pvt.LTD           AWS    KT   3 Months    Channai,KT
# 8    9       UVW  institute .Ltd    Networking    WB   3 Months    Kolkata,WB
# 9   10      GHI   institute .Ltd            AI    AP  18 Months  Hyderabad,AP
# 10  11          IJK   institute             DL    MP   3 Months     Bhopal,MP
# ...

# %%
a.drop(2,axis=0,inplace=True)

# %%
a
# Out:
#     sr                 institute        course state       time    city_state
# 0    1        PQR institute .Pvt            BI    MH   9 Months     Mumbai,MH
# 1    2    ABC institute .Pvt.LTD            AI    UP  18 Months      Delhi,UP
# 3    4   RST  institute .Pvt.LTD            ML    MP   3 Months     Bhopal,MP
# 4    5   EFG  institute .Pvt.LTD            DL    MH   3 Months     Mumbai,MH
# 5    6           LMN  institute          Could    AP   4 Months  Hyderabad,AP
# 6    7      DEF   institute .Ltd      Web Serv    BH   4 Months      Patna,BH
# 7    8   PQR  institute .Pvt.LTD           AWS    KT   3 Months    Channai,KT
# 8    9       UVW  institute .Ltd    Networking    WB   3 Months    Kolkata,WB
# 9   10      GHI   institute .Ltd            AI    AP  18 Months  Hyderabad,AP
# 10  11          IJK   institute             DL    MP   3 Months     Bhopal,MP
# 11  12      KLM   institute .Ltd  Data Science    MH  11 Months       Pune,MH
# ...

# %%
b.drop([2,3,4,5,6,7,8],axis=0)
# Out:
#      age gender     department  Id_no
# 0     24      M     technician  85711
# 1     53      F          other  94043
# 9     53      M         lawyer  90703
# 10    39      F          other  30329
# 11    28      F          other  06405
# ..   ...    ...            ...    ...
# 938   26      F        student  33319
# 939   32      M  administrator  02215
# 940   20      M        student  97229
# 941   48      F      librarian  78209
# 942   22      M        student  77841
#
# [936 rows x 4 columns]

# %%
b
# Out:
#      age gender     department  Id_no
# 0     24      M     technician  85711
# 1     53      F          other  94043
# 2     23      M         writer  32067
# 3     24      M     technician  43537
# 4     33      F          other  15213
# ..   ...    ...            ...    ...
# 938   26      F        student  33319
# 939   32      M  administrator  02215
# 940   20      M        student  97229
# 941   48      F      librarian  78209
# 942   22      M        student  77841
#
# [943 rows x 4 columns]

# %%
b.drop([2,3,4,5,6,7,8],axis=0,inplace=True)

# %%
b
# Out:
#      age gender     department  Id_no
# 0     24      M     technician  85711
# 1     53      F          other  94043
# 9     53      M         lawyer  90703
# 10    39      F          other  30329
# 11    28      F          other  06405
# ..   ...    ...            ...    ...
# 938   26      F        student  33319
# 939   32      M  administrator  02215
# 940   20      M        student  97229
# 941   48      F      librarian  78209
# 942   22      M        student  77841
#
# [936 rows x 4 columns]

# %%
a.set_index('sr',inplace=True)

# %%
a
# Out:
#                    institute        course state       time    city_state
# sr
# 1         PQR institute .Pvt            BI    MH   9 Months     Mumbai,MH
# 2     ABC institute .Pvt.LTD            AI    UP  18 Months      Delhi,UP
# 4    RST  institute .Pvt.LTD            ML    MP   3 Months     Bhopal,MP
# 5    EFG  institute .Pvt.LTD            DL    MH   3 Months     Mumbai,MH
# 6            LMN  institute          Could    AP   4 Months  Hyderabad,AP
# 7       DEF   institute .Ltd      Web Serv    BH   4 Months      Patna,BH
# 8    PQR  institute .Pvt.LTD           AWS    KT   3 Months    Channai,KT
# 9        UVW  institute .Ltd    Networking    WB   3 Months    Kolkata,WB
# 10      GHI   institute .Ltd            AI    AP  18 Months  Hyderabad,AP
# 11          IJK   institute             DL    MP   3 Months     Bhopal,MP
# 12      KLM   institute .Ltd  Data Science    MH  11 Months       Pune,MH
# 13       STU  institute .Ltd            BI    UP   6 Months      Delhi,UP
# ...

# %%
a.drop(1,axis=0)
# Out:
#                    institute        course state       time    city_state
# sr
# 2     ABC institute .Pvt.LTD            AI    UP  18 Months      Delhi,UP
# 4    RST  institute .Pvt.LTD            ML    MP   3 Months     Bhopal,MP
# 5    EFG  institute .Pvt.LTD            DL    MH   3 Months     Mumbai,MH
# 6            LMN  institute          Could    AP   4 Months  Hyderabad,AP
# 7       DEF   institute .Ltd      Web Serv    BH   4 Months      Patna,BH
# 8    PQR  institute .Pvt.LTD           AWS    KT   3 Months    Channai,KT
# 9        UVW  institute .Ltd    Networking    WB   3 Months    Kolkata,WB
# 10      GHI   institute .Ltd            AI    AP  18 Months  Hyderabad,AP
# 11          IJK   institute             DL    MP   3 Months     Bhopal,MP
# 12      KLM   institute .Ltd  Data Science    MH  11 Months       Pune,MH
# 13       STU  institute .Ltd            BI    UP   6 Months      Delhi,UP
# 14   XYZ  institute .Pvt.LTD         Could    MH   3 Months     Mumbai,MH
# ...

# %%
a
# Out:
#                    institute        course state       time    city_state
# sr
# 1         PQR institute .Pvt            BI    MH   9 Months     Mumbai,MH
# 2     ABC institute .Pvt.LTD            AI    UP  18 Months      Delhi,UP
# 4    RST  institute .Pvt.LTD            ML    MP   3 Months     Bhopal,MP
# 5    EFG  institute .Pvt.LTD            DL    MH   3 Months     Mumbai,MH
# 6            LMN  institute          Could    AP   4 Months  Hyderabad,AP
# 7       DEF   institute .Ltd      Web Serv    BH   4 Months      Patna,BH
# 8    PQR  institute .Pvt.LTD           AWS    KT   3 Months    Channai,KT
# 9        UVW  institute .Ltd    Networking    WB   3 Months    Kolkata,WB
# 10      GHI   institute .Ltd            AI    AP  18 Months  Hyderabad,AP
# 11          IJK   institute             DL    MP   3 Months     Bhopal,MP
# 12      KLM   institute .Ltd  Data Science    MH  11 Months       Pune,MH
# 13       STU  institute .Ltd            BI    UP   6 Months      Delhi,UP
# ...

# %%
a.reset_index(inplace=True)

# %%
a
# Out:
#     sr                 institute        course state       time    city_state
# 0    1        PQR institute .Pvt            BI    MH   9 Months     Mumbai,MH
# 1    2    ABC institute .Pvt.LTD            AI    UP  18 Months      Delhi,UP
# 2    4   RST  institute .Pvt.LTD            ML    MP   3 Months     Bhopal,MP
# 3    5   EFG  institute .Pvt.LTD            DL    MH   3 Months     Mumbai,MH
# 4    6           LMN  institute          Could    AP   4 Months  Hyderabad,AP
# 5    7      DEF   institute .Ltd      Web Serv    BH   4 Months      Patna,BH
# 6    8   PQR  institute .Pvt.LTD           AWS    KT   3 Months    Channai,KT
# 7    9       UVW  institute .Ltd    Networking    WB   3 Months    Kolkata,WB
# 8   10      GHI   institute .Ltd            AI    AP  18 Months  Hyderabad,AP
# 9   11          IJK   institute             DL    MP   3 Months     Bhopal,MP
# 10  12      KLM   institute .Ltd  Data Science    MH  11 Months       Pune,MH
# ...

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
############### methods and attributes inn pandas#######

# %%
a.dtypes
# Out:
# sr             int64
# institute     object
# course        object
# state         object
# time          object
# city_state    object
# dtype: object

# %%
a.shape
# Out:
# (24, 6)

# %%
a.columns
# Out:
# Index(['sr', 'institute', 'course', 'state', 'time', 'city_state'], dtype='object')

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sr          24 non-null     int64
#  1   institute   24 non-null     object
#  2   course      24 non-null     object
#  3   state       24 non-null     object
#  4   time        24 non-null     object
#  5   city_state  24 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.3+ KB

# %%
a.describe()
# Out:
#               sr
# count  24.000000
# mean   13.416667
# std     7.210600
# min     1.000000
# 25%     7.750000
# 50%    13.500000
# 75%    19.250000
# max    25.000000

# %%
a.mean
# Out:
# <bound method DataFrame.mean of     sr                 institute        course state       time    city_state
# 0    1        PQR institute .Pvt            BI    MH   9 Months     Mumbai,MH
# 1    2    ABC institute .Pvt.LTD            AI    UP  18 Months      Delhi,UP
# 2    4   RST  institute .Pvt.LTD            ML    MP   3 Months     Bhopal,MP
# 3    5   EFG  institute .Pvt.LTD            DL    MH   3 Months     Mumbai,MH
# 4    6           LMN  institute          Could    AP   4 Months  Hyderabad,AP
# 5    7      DEF   institute .Ltd      Web Serv    BH   4 Months      Patna,BH
# 6    8   PQR  institute .Pvt.LTD           AWS    KT   3 Months    Channai,KT
# 7    9       UVW  institute .Ltd    Networking    WB   3 Months    Kolkata,WB
# 8   10      GHI   institute .Ltd            AI    AP  18 Months  Hyderabad,AP
# 9   11          IJK   institute             DL    MP   3 Months     Bhopal,MP
# 10  12      KLM   institute .Ltd  Data Science    MH  11 Months       Pune,MH
# ...

# %%
a.describe(include=["object"])
# Out:
#                  institute course state      time city_state
# count                   24     24    24        24         24
# unique                  24      9    10         6         11
# top     PQR institute .Pvt     AI    MH  3 Months  Mumbai,MH
# freq                     1      3     7        11          5

# %%
############ case study ########

# %%
#1
df=pd.read_table("/content/Ecommerce Purchases",sep="")
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
df.tail()
# Out:
#                                                 Address    Lot AM or PM  \
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9995  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/5352 ...
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9997  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9998  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_8;...
# 9999  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
#                        Company       Credit Card CC Exp Date  \
# 9995             Randall-Sloan   342945015358701       03/22
# 9996  Hale, Collins and Wilson   210033169205009       07/25
# ...

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
df["Purchase Price"].mean()
# Out:
# np.float64(50.347302)

# %%
df["Purchase Price"].min()
# Out:
# 0.0

# %%
df["Purchase Price"].max()
# Out:
# 99.99

# %%
df[df.Language =="en"].count()
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %%
df[df.Job=="lawyer"].count()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64
